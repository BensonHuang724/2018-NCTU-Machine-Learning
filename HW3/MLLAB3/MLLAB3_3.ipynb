# %% [markdown]
# # 讀檔

# %%
import numpy as np
import pandas as pd
import math
from numpy.linalg import inv
from matplotlib import pyplot as plt
import cv2
import random
img = cv2.imread('HW3.jpg')
height=60
width=120
img = cv2.resize(img, (width, height), interpolation=cv2.INTER_CUBIC)
img_rgb = img[:,:,::-1]
print( img_rgb.shape )
plt.imshow(img_rgb)
plt.show()
# Out:
# (60, 120, 3)

# %% [markdown]
# # K-means 參數 函數

# %%
def cal_dis(x1,y1,z1,x2,y2,z2):
    return ((x1-x2)**2+(y1-y2)**2+(z1-z2)**2)**0.5
f = open('A.txt', 'w', encoding = 'UTF-8')
k=20
kmeans_iteration=10
uk=np.ones((k,3))
rnk=np.zeros((height,width))
for i in range(k):
    for j in range(3):
        uk[i][j]=random.randint(0,256)

# %% [markdown]
# # K-means

# %%
for iteration in range(kmeans_iteration):
    print("iteration:",iteration,", E step")
    for i in range(height):
        for j in range(width):
            min_uk=-1
            min_dis=1000000000
            for m in range(k):
                distance=cal_dis(img[i][j][0],img[i][j][1],img[i][j][2], uk[m][0], uk[m][1], uk[m][2])
                if distance<min_dis:
                    min_dis=distance
                    min_uk=m
            rnk[i][j]=min_uk
           ## print("rnk[",i,"][",j,"]=",min_uk)
    print("iteration:",iteration,", M step")
    for i in range(k):
        counter0=counter1=counter2=num=0
        for m in range(height):
            for n in range(width):
                if rnk[m][n]==i:
                    counter0=counter0+img[m][n][0]
                    counter1=counter1+img[m][n][1]
                    counter2=counter2+img[m][n][2]
                    num=num+1
        if num==0:
            print("u",i,": ")
            uk[i][0]=random.randint(0,256)    
            uk[i][1]=random.randint(0,256)    
            uk[i][2]=random.randint(0,256)    
        if num!=0:
            print("u",i,": "," ",counter0/num," ",counter1/num," ",counter2/num)
            uk[i][0]=counter0/num
            uk[i][1]=counter1/num
            uk[i][2]=counter2/num
            
    img_rgbtemp=np.zeros((height,width,3))
    for i in range(height):
        for j in range(width):
            group=int(rnk[i][j])
            img_rgbtemp[i][j][0]=int ( uk[ group  ][0] )
            img_rgbtemp[i][j][1]=int ( uk[ group  ][1] )
            img_rgbtemp[i][j][2]=int ( uk[ group  ][2] )
    img_rgbtemp2 = img_rgbtemp.astype(np.int32)
    img_rgb  = img_rgbtemp2[:,:,::-1]
    img_rgb2 = img[:,:,::-1]
    plt.imshow(img_rgb)
    plt.show()
# Out:
# iteration: 0 , E step
# iteration: 0 , M step
# u 0 :
# u 1 :    93.64   58.12533333333333   25.584
# u 2 :    19.838028169014084   29.253521126760564   33.852112676056336
# u 3 :    13.322248614410135   77.17498020585907   100.26840855106889
# u 4 :    6.8313725490196076   101.36078431372549   143.84313725490196
# u 5 :    146.28571428571428   184.0   186.28571428571428
# u 6 :    63.71768707482993   69.60204081632654   91.04081632653062
# u 7 :
# u 8 :    92.5609756097561   97.70731707317073   127.1219512195122
# u 9 :
# u 10 :    128.44444444444446   99.22222222222223   67.22222222222223
# u 11 :
# u 12 :    18.0   135.5   142.25
# u 13 :
# u 12 :    9.786259541984732   111.61068702290076   146.72010178117048
# u 13 :    9.930693069306932   128.87788778877888   168.01980198019803
# u 14 :    239.4461035930938   209.90573961735885   186.51143257116192
# u 15 :    156.66197183098592   138.5211267605634   141.09154929577466
# u 16 :    21.490683229813666   150.68944099378882   193.07453416149067
# u 17 :    67.98203592814372   84.38922155688623   108.19760479041916
# u 18 :    55.244897959183675   129.3265306122449   151.58163265306123
# u 19 :    3.6666666666666665   3.1666666666666665   114.5
# iteration: 9 , E step
# iteration: 9 , M step
# u 0 :    117.0   172.91304347826087   187.04347826086956
# u 1 :    81.86206896551724   46.95019157088122   8.10727969348659
# u 2 :    6.418238993710692   39.05345911949686   54.770440251572325
# u 3 :    10.290018832391715   65.58003766478343   91.15819209039547
# u 4 :    10.866962305986696   90.15742793791574   120.77827050997783
# u 5 :    189.97652582159625   166.093896713615   154.8544600938967
# u 6 :    52.42767295597484   60.20125786163522   76.50943396226415
# u 7 :    223.0152505446623   192.03485838779957   166.40958605664488
# u 8 :    114.97560975609755   107.77439024390245   118.6829268292683
# u 9 :    204.94838709677418   193.16774193548386   183.92903225806452
# u 10 :    108.19072164948453   77.87113402061856   61.98969072164948
# u 11 :    247.4388888888889   234.07222222222222   223.425
# u 12 :    9.432835820895523   110.7363184079602   146.26119402985074
# u 13 :    10.415094339622641   129.30817610062894   167.9559748427673
# u 14 :    239.62180974477957   210.14709976798144   186.86357308584687
# u 15 :    155.64383561643837   138.08904109589042   141.94520547945206
# u 16 :    21.774834437086092   151.35761589403972   194.43708609271522
# u 17 :    67.61271676300578   83.64161849710983   107.38150289017341
# u 18 :    54.31372549019608   129.57843137254903   151.59803921568627
# u 19 :    3.6666666666666665   3.1666666666666665   114.5

# %% [markdown]
# # GMM

# %%
def gaussian(mean,var,x,D):
    leftterm_Denominator=( ((2*math.pi)**D)*np.linalg.det(var) )**0.5
    rightterm_power=-0.5*(  ((x-mean).T).dot(  np.linalg.pinv(var)  ).dot((x-mean))  )
    #print(leftterm_Denominator)
    #print(rightterm_power)
    return (1.0/leftterm_Denominator*np.exp(rightterm_power) )

D=3
GMM_iteration=100

responsibility=np.zeros((height,width,k))
variance=np.zeros((k,D,D))
for i in range(k):
    variance[i]=128*np.eye(D, dtype = 'int')
latent_var=np.zeros((k))
for i in range(height):
    for j in range(width):
        latent_var  [int(rnk[i][j]) ] =latent_var[ int(rnk[i][j]) ]+1
sum_temp=0
sum_temp2=0
for m in range(k):
    sum_temp=sum_temp+latent_var[m]
#print(sum_temp)
for m in range(k):
    latent_var[m]=latent_var[m]/sum_temp
    sum_temp2=sum_temp2+latent_var[m]
    #print(latent_var[m],sum_temp2)

# %%
log_likelyhood=np.zeros((100))
for iteraion in range(GMM_iteration):
    print("第",iteraion,"次 E_step:update resposibility")
    for i in range(height):
        #print("process column:",i)
        for j in range(width):
            res_denomi=0
            for m in range(k):
                #print("debug:",uk[m]," ",img[i][j])
                #print("mode1:",latent_var[m]," ",gaussian(uk[m],variance[m],img[i][j],3))
                res_denomi=res_denomi+latent_var[m]*  gaussian(uk[m],variance[m],img[i][j],3)
            for m in range(k):
                #print("mode2,",m," ",latent_var[m]," ", gaussian(uk[m],variance[m],img[i][j],3)," ",res_denomi)
                responsibility[i][j][m]=latent_var[m]*  gaussian(uk[m],variance[m],img[i][j],3) / res_denomi
                #if((i+1)%20==0):
                    #print(i+1,"responsibility,",i,j,m," ", responsibility[i][j][m])
                
    print("第",iteraion,"次 M_step")
    #print("                        update NK")
    NK=np.zeros((k)) 
    for m in range(k):
        for i in range(height):
            for j in range(width):
                  NK[m]= NK[m]+responsibility[i][j][m]
    #for m in range(k):
          #print( "NK",m,":",NK[m])
                        
    #print("\n","                        update mean")
    for m in range(k):
        #print("process u ",m)
        uk[m][0]=uk[m][1]=uk[m][2]=0
        for i in range(height):
            for j in range(width):
                uk[m][0]=uk[m][0]+responsibility[i][j][m]*img[i][j][0]
                uk[m][1]=uk[m][1]+responsibility[i][j][m]*img[i][j][1]
                uk[m][2]=uk[m][2]+responsibility[i][j][m]*img[i][j][2]
        if NK[m]!=0:
            uk[m]=uk[m]/NK[m]
        else:
            uk[m][0]=random.randint(0,256)
            uk[m][1]=random.randint(0,256)  
            uk[m][2]=random.randint(0,256)  
                
    #print("                        update var ")
    for m in range(k):
        #print("process var ",m)
        var_temp=np.zeros((3,3))
        for i in range(height):
            for j in range(width):
                var_temp=var_temp+responsibility[i][j][m]*( (img[i][j]-uk[m]).T.dot((img[i][j]-uk[m])) )
        var_temp=var_temp/NK[m]
                
    
    #print("                        update latent")   
    for m in range(k):
        latent_var[m]=NK[m]/(width*height)
        
        
    log_likely=0
    for i in range(height):
        for j in range(width):
            temp_value=0
            for m in range(k):
                temp_value=temp_value+latent_var[m]*gaussian(uk[m],variance[m],img[i][j],3)
            log_likely=log_likely+math.log(temp_value)
    
    log_likelyhood[iteraion]=log_likely
    print("log_likely:",log_likely)
    
img_GMM=np.zeros((height,width,3))
for i in range(height):
    for j in range(width):
        max_class=-1
        max_respon=-1
        for m in range(k):
            if responsibility[i][j][m]>max_respon:
                max_class=m
                max_respon=responsibility[i][j][m]
        img_GMM[i][j]=uk[max_class]
img_GMM = img_GMM.astype(np.int32)
img_GMM  = img_GMM[:,:,::-1]
print( img_GMM.shape )
plt.imshow(img_GMM)
plt.show()
# Out:
# 第 0 次 E_step:update resposibility
# 第 0 次 M_step
# log_likely: -96188.64670878886
# 第 1 次 E_step:update resposibility
# 第 1 次 M_step
# log_likely: -96061.44605230012
# 第 2 次 E_step:update resposibility
# 第 2 次 M_step
# log_likely: -95979.78015981424
# 第 3 次 E_step:update resposibility
# 第 3 次 M_step
# log_likely: -95941.32879535454
# 第 4 次 E_step:update resposibility
# 第 4 次 M_step
# log_likely: -95919.2871806949
# 第 5 次 E_step:update resposibility
# 第 5 次 M_step
# log_likely: -95901.84180396683
# 第 6 次 E_step:update resposibility
# 第 6 次 M_step
# log_likely: -95886.96518807362
# 第 7 次 E_step:update resposibility
# 第 7 次 M_step
# log_likely: -95874.15259485102
# 第 8 次 E_step:update resposibility
# 第 8 次 M_step
# log_likely: -95863.21157700109
# 第 9 次 E_step:update resposibility
# 第 9 次 M_step
# log_likely: -95854.10315320583
# 第 10 次 E_step:update resposibility
# 第 10 次 M_step
# log_likely: -95846.83991641567
# 第 11 次 E_step:update resposibility
# 第 11 次 M_step
# log_likely: -95841.34918449432
# 第 12 次 E_step:update resposibility
# 第 12 次 M_step
# log_likely: -95837.39844369603
# 第 13 次 E_step:update resposibility
# 第 13 次 M_step
# log_likely: -95834.65127388532
# 第 14 次 E_step:update resposibility
# 第 14 次 M_step
# log_likely: -95832.77290320037
# 第 15 次 E_step:update resposibility
# 第 15 次 M_step
# log_likely: -95831.49287952909
# 第 16 次 E_step:update resposibility
# 第 16 次 M_step
# log_likely: -95830.6158758024
# 第 17 次 E_step:update resposibility
# 第 17 次 M_step
# log_likely: -95830.00847516843
# 第 18 次 E_step:update resposibility
# 第 18 次 M_step
# log_likely: -95829.58180892775
# 第 19 次 E_step:update resposibility
# 第 19 次 M_step
# log_likely: -95829.2772143356
# 第 20 次 E_step:update resposibility
# 第 20 次 M_step
# log_likely: -95829.0559792611
# 第 21 次 E_step:update resposibility
# 第 21 次 M_step
# log_likely: -95828.89242950403
# 第 22 次 E_step:update resposibility
# 第 22 次 M_step
# log_likely: -95828.76939052006
# 第 23 次 E_step:update resposibility
# 第 23 次 M_step
# log_likely: -95828.67524315215
# 第 24 次 E_step:update resposibility
# 第 24 次 M_step
# log_likely: -95828.60202186773
# 第 25 次 E_step:update resposibility
# 第 25 次 M_step
# log_likely: -95828.54418607464
# 第 26 次 E_step:update resposibility
# 第 26 次 M_step
# log_likely: -95828.49782336215
# 第 27 次 E_step:update resposibility
# 第 27 次 M_step
# log_likely: -95828.46012939884
# 第 28 次 E_step:update resposibility
# 第 28 次 M_step
# log_likely: -95828.42906534276
# 第 29 次 E_step:update resposibility
# 第 29 次 M_step
# log_likely: -95828.40312958935
# 第 30 次 E_step:update resposibility
# 第 30 次 M_step
# log_likely: -95828.38120366709
# 第 31 次 E_step:update resposibility
# 第 31 次 M_step
# log_likely: -95828.36244660543
# 第 32 次 E_step:update resposibility
# 第 32 次 M_step
# log_likely: -95828.34622131457
# 第 33 次 E_step:update resposibility
# 第 33 次 M_step
# log_likely: -95828.33204235854
# 第 34 次 E_step:update resposibility
# 第 34 次 M_step
# log_likely: -95828.31953820396
# 第 35 次 E_step:update resposibility
# 第 35 次 M_step
# log_likely: -95828.30842342917
# 第 36 次 E_step:update resposibility
# 第 36 次 M_step
# log_likely: -95828.29847791471
# 第 37 次 E_step:update resposibility
# 第 37 次 M_step
# log_likely: -95828.28953104411
# 第 38 次 E_step:update resposibility
# 第 38 次 M_step
# log_likely: -95828.28144957953
# 第 39 次 E_step:update resposibility
# 第 39 次 M_step
# log_likely: -95828.27412832897
# 第 40 次 E_step:update resposibility
# 第 40 次 M_step
# log_likely: -95828.26748297192
# 第 41 次 E_step:update resposibility
# 第 41 次 M_step
# log_likely: -95828.2614445878
# 第 42 次 E_step:update resposibility
# 第 42 次 M_step
# log_likely: -95828.25595554523
# 第 43 次 E_step:update resposibility
# 第 43 次 M_step
# log_likely: -95828.25096647376
# 第 44 次 E_step:update resposibility
# 第 44 次 M_step
# log_likely: -95828.24643408677
# 第 45 次 E_step:update resposibility
# 第 45 次 M_step
# log_likely: -95828.24231965675
# 第 46 次 E_step:update resposibility
# 第 46 次 M_step
# log_likely: -95828.23858798618
# 第 47 次 E_step:update resposibility
# 第 47 次 M_step
# log_likely: -95828.23520672579
# 第 48 次 E_step:update resposibility
# 第 48 次 M_step
# log_likely: -95828.23214594783
# 第 49 次 E_step:update resposibility
# 第 49 次 M_step
# log_likely: -95828.22937787292
# 第 50 次 E_step:update resposibility
# 第 50 次 M_step
# log_likely: -95828.22687669973
# 第 51 次 E_step:update resposibility
# 第 51 次 M_step
# log_likely: -95828.22461849441
# 第 52 次 E_step:update resposibility
# 第 52 次 M_step
# log_likely: -95828.22258110307
# 第 53 次 E_step:update resposibility
# 第 53 次 M_step
# log_likely: -95828.2207440786
# 第 54 次 E_step:update resposibility
# 第 54 次 M_step
# log_likely: -95828.21908860498
# 第 55 次 E_step:update resposibility
# 第 55 次 M_step
# log_likely: -95828.21759742034
# 第 56 次 E_step:update resposibility
# 第 56 次 M_step
# log_likely: -95828.21625473497
# 第 57 次 E_step:update resposibility
# 第 57 次 M_step
# log_likely: -95828.21504614194
# 第 58 次 E_step:update resposibility
# 第 58 次 M_step
# log_likely: -95828.2139585268
# 第 59 次 E_step:update resposibility
# 第 59 次 M_step
# log_likely: -95828.21297997927
# 第 60 次 E_step:update resposibility
# 第 60 次 M_step
# log_likely: -95828.21209970035
# 第 61 次 E_step:update resposibility
# 第 61 次 M_step
# log_likely: -95828.2113079148
# 第 62 次 E_step:update resposibility
# 第 62 次 M_step
# log_likely: -95828.2105957854
# 第 63 次 E_step:update resposibility
# 第 63 次 M_step
# log_likely: -95828.20995533255
# 第 64 次 E_step:update resposibility
# 第 64 次 M_step
# log_likely: -95828.2093793581
# 第 65 次 E_step:update resposibility
# 第 65 次 M_step
# log_likely: -95828.20886137417
# 第 66 次 E_step:update resposibility
# 第 66 次 M_step
# log_likely: -95828.20839553558
# 第 67 次 E_step:update resposibility
# 第 67 次 M_step
# log_likely: -95828.20797658229
# 第 68 次 E_step:update resposibility
# 第 68 次 M_step
# log_likely: -95828.20759978003
# 第 69 次 E_step:update resposibility
# 第 69 次 M_step
# log_likely: -95828.20726087013
# 第 70 次 E_step:update resposibility
# 第 70 次 M_step
# log_likely: -95828.206956024
# 第 71 次 E_step:update resposibility
# 第 71 次 M_step
# log_likely: -95828.20668179975
# 第 72 次 E_step:update resposibility
# 第 72 次 M_step
# log_likely: -95828.20643510256
# 第 73 次 E_step:update resposibility
# 第 73 次 M_step
# log_likely: -95828.20621315259
# 第 74 次 E_step:update resposibility
# 第 74 次 M_step
# log_likely: -95828.20601345073
# 第 75 次 E_step:update resposibility
# 第 75 次 M_step
# log_likely: -95828.20583375171
# 第 76 次 E_step:update resposibility
# 第 76 次 M_step
# log_likely: -95828.20567203786
# 第 77 次 E_step:update resposibility
# 第 77 次 M_step
# log_likely: -95828.2055264973
# 第 78 次 E_step:update resposibility
# 第 78 次 M_step
# log_likely: -95828.20539550098
# 第 79 次 E_step:update resposibility
# 第 79 次 M_step
# log_likely: -95828.20527758387
# 第 80 次 E_step:update resposibility
# 第 80 次 M_step
# log_likely: -95828.2051714317
# 第 81 次 E_step:update resposibility
# 第 81 次 M_step
# log_likely: -95828.20507586267
# 第 82 次 E_step:update resposibility
# 第 82 次 M_step
# log_likely: -95828.2049898133
# 第 83 次 E_step:update resposibility
# 第 83 次 M_step
# log_likely: -95828.20491233015
# 第 84 次 E_step:update resposibility
# 第 84 次 M_step
# log_likely: -95828.20484255336
# 第 85 次 E_step:update resposibility
# 第 85 次 M_step
# log_likely: -95828.20477971097
# 第 86 次 E_step:update resposibility
# 第 86 次 M_step
# log_likely: -95828.20472311143
# 第 87 次 E_step:update resposibility
# 第 87 次 M_step
# log_likely: -95828.20467212895
# 第 88 次 E_step:update resposibility
# 第 88 次 M_step
# log_likely: -95828.20462620286
# 第 89 次 E_step:update resposibility
# 第 89 次 M_step
# log_likely: -95828.20458482912
# 第 90 次 E_step:update resposibility
# 第 90 次 M_step
# log_likely: -95828.20454755389
# 第 91 次 E_step:update resposibility
# 第 91 次 M_step
# log_likely: -95828.20451396765
# 第 92 次 E_step:update resposibility
# 第 92 次 M_step
# log_likely: -95828.2044837044
# 第 93 次 E_step:update resposibility
# 第 93 次 M_step
# log_likely: -95828.20445643362
# 第 94 次 E_step:update resposibility
# 第 94 次 M_step
# log_likely: -95828.20443185684
# 第 95 次 E_step:update resposibility
# 第 95 次 M_step
# log_likely: -95828.20440970744
# 第 96 次 E_step:update resposibility
# 第 96 次 M_step
# log_likely: -95828.20438974434
# 第 97 次 E_step:update resposibility
# 第 97 次 M_step
# log_likely: -95828.20437175107
# 第 98 次 E_step:update resposibility
# 第 98 次 M_step
# log_likely: -95828.20435553149
# 第 99 次 E_step:update resposibility
# 第 99 次 M_step
# log_likely: -95828.20434091057
# (60, 120, 3)

# %%
img_GMM=np.zeros((height,width,3))
for i in range(height):
    for j in range(width):
        temp_sum=0
        for m in range(k):
                temp_sum=temp_sum+responsibility[i][j][m]
        for m in range(k):
            img_GMM[i][j]=img_GMM[i][j]+responsibility[i][j][m]/temp_sum*uk[m]
img_GMM = img_GMM.astype(np.int32)
img_GMM  = img_GMM[:,:,::-1]
print( img_GMM.shape )
plt.imshow(img_GMM)
plt.show()
# Out:
# (60, 120, 3)

# %% [markdown]
# # show curve

# %%
x_temp=np.linspace(0,99,100)
plt.plot(x_temp,log_likelyhood,  color='red')
plt.xlabel('iteration')
plt.ylabel('log_likelyhood')
plt.title('GMM,k=5')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
